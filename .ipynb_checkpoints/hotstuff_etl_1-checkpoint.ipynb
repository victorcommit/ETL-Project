# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#Store CSV into DataeFrame
csv_file = "Resources/Hot Stuff.csv"
hot_stuff_df = pd.read_csv(csv_file, encoding='utf-8')
hot_stuff_df.head()
# Out:
#                                                  url    weekid  week_position  \
# 0  http://www.billboard.com/charts/hot-100/1958-0...    8/2/58              1
# 1  http://www.billboard.com/charts/hot-100/1995-1...   12/2/95              1
# 2  http://www.billboard.com/charts/hot-100/1997-1...  10/11/97              1
# 3  http://www.billboard.com/charts/hot-100/2006-0...    7/1/06              1
# 4  http://www.billboard.com/charts/hot-100/2009-1...  10/24/09              1
#
#                                                 song  \
# 0                                   Poor Little Fool
# 1                                      One Sweet Day
# 2  Candle In The Wind 1997/Something About The Wa...
# 3                                Do I Make You Proud
# 4                                                  3
#
#                     performer  \
# 0                Ricky Nelson
# 1  Mariah Carey & Boyz II Men
# 2                  Elton John
# 3                Taylor Hicks
# 4              Britney Spears
#
#                                               songid  instance  \
# 0                       Poor Little FoolRicky Nelson         1
# 1            One Sweet DayMariah Carey & Boyz II Men         1
# 2  Candle In The Wind 1997/Something About The Wa...         1
# 3                    Do I Make You ProudTaylor Hicks         1
# 4                                    3Britney Spears         1
#
#    previous_week Position  peak_position  weeks_on_chart
# 0                     NaN              1               1
# 1                     NaN              1               1
# 2                     NaN              1               1
# 3                     NaN              1               1
# 4                     NaN              1               1

# %%
#Create new data with select columns
new_hot_stuff_df = hot_stuff_df[['weekid', 'song', 'performer','songid']]. copy()
new_hot_stuff_df.head()
# Out:
#      weekid                                               song  \
# 0    8/2/58                                   Poor Little Fool
# 1   12/2/95                                      One Sweet Day
# 2  10/11/97  Candle In The Wind 1997/Something About The Wa...
# 3    7/1/06                                Do I Make You Proud
# 4  10/24/09                                                  3
#
#                     performer  \
# 0                Ricky Nelson
# 1  Mariah Carey & Boyz II Men
# 2                  Elton John
# 3                Taylor Hicks
# 4              Britney Spears
#
#                                               songid
# 0                       Poor Little FoolRicky Nelson
# 1            One Sweet DayMariah Carey & Boyz II Men
# 2  Candle In The Wind 1997/Something About The Wa...
# 3                    Do I Make You ProudTaylor Hicks
# 4                                    3Britney Spears

# %%
new_hot_stuff_df['year'] = pd.DatetimeIndex(new_hot_stuff_df['weekid']).year
new_hot_stuff_df.head(20)
# Out:
#       weekid                                               song  \
# 0     8/2/58                                   Poor Little Fool
# 1    12/2/95                                      One Sweet Day
# 2   10/11/97  Candle In The Wind 1997/Something About The Wa...
# 3     7/1/06                                Do I Make You Proud
# 4   10/24/09                                                  3
# 5    2/26/11                                      Born This Way
# 6     3/3/12                                         Part Of Me
# 7     9/6/14                                       Shake It Off
# 8    2/20/16                                         Pillowtalk
# 9    5/28/16                            Can't Stop The Feeling!
# 10   1/28/17                                       Shape Of You
# 11  11/17/18                                      Thank U, Next
# 12    2/2/19                                            7 Rings
# 13   3/16/19                                             Sucker
# 14    8/2/58                                           Patricia
# 15    4/6/96                                  Always Be My Baby
# 16   5/11/96                                     Tha Crossroads
# 17   9/27/97                            4 Seasons Of Loneliness
# 18   8/30/08                                              Crush
# 19   8/29/09                                Party In The U.S.A.
#
#                         performer  \
# 0                    Ricky Nelson
# 1      Mariah Carey & Boyz II Men
# 2                      Elton John
# 3                    Taylor Hicks
# 4                  Britney Spears
# 5                       Lady Gaga
# 6                      Katy Perry
# 7                    Taylor Swift
# 8                            Zayn
# 9               Justin Timberlake
# 10                     Ed Sheeran
# 11                  Ariana Grande
# 12                  Ariana Grande
# 13                 Jonas Brothers
# 14  Perez Prado And His Orchestra
# 15                   Mariah Carey
# 16           Bone Thugs-N-Harmony
# 17                    Boyz II Men
# 18                David Archuleta
# 19                    Miley Cyrus
#
#                                                songid  year
# 0                        Poor Little FoolRicky Nelson  2058
# 1             One Sweet DayMariah Carey & Boyz II Men  1995
# 2   Candle In The Wind 1997/Something About The Wa...  1997
# 3                     Do I Make You ProudTaylor Hicks  2006
# 4                                     3Britney Spears  2009
# 5                              Born This WayLady Gaga  2011
# 6                                Part Of MeKaty Perry  2012
# 7                            Shake It OffTaylor Swift  2014
# 8                                      PillowtalkZayn  2016
# 9            Can't Stop The Feeling!Justin Timberlake  2016
# 10                             Shape Of YouEd Sheeran  2017
# 11                         Thank U, NextAriana Grande  2018
# 12                               7 RingsAriana Grande  2019
# 13                               SuckerJonas Brothers  2019
# 14              PatriciaPerez Prado And His Orchestra  2058
# 15                      Always Be My BabyMariah Carey  1996
# 16                 Tha CrossroadsBone Thugs-N-Harmony  1996
# 17                 4 Seasons Of LonelinessBoyz II Men  1997
# 18                               CrushDavid Archuleta  2008
# 19                     Party In The U.S.A.Miley Cyrus  2009

# %%
df = new_hot_stuff_df

# %%
#Store Additional CSV data into DataFrame
top10_file = "Resources/top10s.csv"
top10_df = pd.read_csv(top10_file, encoding='latin-1')
top10_df.head()
# Out:
#    Unnamed: 0                 title      artist        top_genre  year  bpm  \
# 0           1      Hey, Soul Sister       Train       neo mellow  2010   97
# 1           2  Love The Way You Lie      Eminem  detroit hip hop  2010   87
# 2           3               TiK ToK       Kesha        dance pop  2010  120
# 3           4           Bad Romance   Lady Gaga        dance pop  2010  119
# 4           5  Just the Way You Are  Bruno Mars              pop  2010  109
#
#    nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0    89    67  -4     8   80  217     19     4   83
# 1    93    75  -5    52   64  263     24    23   82
# 2    84    76  -3    29   71  200     10    14   80
# 3    92    70  -4     8   71  295      0     4   79
# 4    84    64  -5     9   43  221      2     4   78

# %%
#Clean DataFrame
new_top10_df = top10_df[['title', 'artist', 'top_genre','year']]. copy()
new_top10_df.head()
# Out:
#                   title      artist        top_genre  year
# 0      Hey, Soul Sister       Train       neo mellow  2010
# 1  Love The Way You Lie      Eminem  detroit hip hop  2010
# 2               TiK ToK       Kesha        dance pop  2010
# 3           Bad Romance   Lady Gaga        dance pop  2010
# 4  Just the Way You Are  Bruno Mars              pop  2010

# %%
#Connect to local SQL database
connection_string = "postgres:postgres@localhost:5432/hotstuff_etl"
engine = create_engine(f'postgresql://{connection_string}')

# %%
#Check tables
engine.table_names()
# Out:
# ['spotify_list', 'hotstuff']

# %%
new_top10_df.year.dtype
# Out:
# dtype('int64')

# %%
#Load CSV converted DataFrame into database
new_hot_stuff_df.to_sql(name='hotstuff', 
                        con=engine, 
                        if_exists='append',
                        index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UndefinedColumn: column "year" of relation "hotstuff" does not exist
# LINE 1: ...T INTO hotstuff (weekid, song, performer, songid, year) VALU...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-141-881dcfeba577> in <module>
#       3                         con=engine,
#       4                         if_exists='append',
# ----> 5                         index=False)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1318         )
#    1319         table.create()
# -> 1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#    1322             # check for potentially case sensitivity issues (GH7815)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     754
#     755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 756                 exec_insert(conn, keys, chunk_iter)
#     757
#     758     def _query_iterator(
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         """
#     669         data = [dict(zip(keys, row)) for row in data_iter]
# --> 670         conn.execute(self.table.insert(), data)
#     671
#     672     def _execute_insert_multi(self, conn, keys, data_iter):
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                 if not evt_handled:
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#    1231             elif not parameters and context.no_parameters:
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "year" of relation "hotstuff" does not exist
# LINE 1: ...T INTO hotstuff (weekid, song, performer, songid, year) VALU...
#                                                              ^
#
# [SQL: INSERT INTO hotstuff (weekid, song, performer, songid, year) VALUES (%(weekid)s, %(song)s, %(performer)s, %(songid)s, %(year)s)]
# [parameters: ({'weekid': '8/2/58', 'song': 'Poor Little Fool', 'performer': 'Ricky Nelson', 'songid': 'Poor Little FoolRicky Nelson', 'year': 2058}, {'weekid': '12/2/95', 'song': 'One Sweet Day', 'performer': 'Mariah Carey & Boyz II Men', 'songid': 'One Sweet DayMariah Carey & Boyz II Men', 'year': 1995}, {'weekid': '10/11/97', 'song': 'Candle In The Wind 1997/Something About The Way You Look Tonight', 'performer': 'Elton John', 'songid': 'Candle In The Wind 1997/Something About The Way You Look TonightElton John', 'year': 1997}, {'weekid': '7/1/06', 'song': 'Do I Make You Proud', 'performer': 'Taylor Hicks', 'songid': 'Do I Make You ProudTaylor Hicks', 'year': 2006}, {'weekid': '10/24/09', 'song': '3', 'performer': 'Britney Spears', 'songid': '3Britney Spears', 'year': 2009}, {'weekid': '2/26/11', 'song': 'Born This Way', 'performer': 'Lady Gaga', 'songid': 'Born This WayLady Gaga', 'year': 2011}, {'weekid': '3/3/12', 'song': 'Part Of Me', 'performer': 'Katy Perry', 'songid': 'Part Of MeKaty Perry', 'year': 2012}, {'weekid': '9/6/14', 'song': 'Shake It Off', 'performer': 'Taylor Swift', 'songid': 'Shake It OffTaylor Swift', 'year': 2014}  ... displaying 10 of 320495 total bound parameter sets ...  {'weekid': '12/21/19', 'song': 'Jingle Bell Rock', 'performer': 'Bobby Helms', 'songid': 'Jingle Bell RockBobby Helms', 'year': 2019}, {'weekid': '12/28/19', 'song': 'Jingle Bell Rock', 'performer': 'Bobby Helms', 'songid': 'Jingle Bell RockBobby Helms', 'year': 2019})]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
new_top10_df.to_sql(name='spotify_list',
                   con= engine,
                   if_exists='append',
                   index=False)

# %%
pd.read_sql_query('select * from spotify_list', con=engine).head()
